# %% [markdown]
# # Maxabi
#
#
# Nous allons utiliser la base de données `test`, dans laquelle se trouve la collection `restaurants`. Celle-ci est composée de plus de 25000 retaurants new-yorkais, avec des évaluations de ceux-ci.
#
# 1. Créer une connexion vers cette collection
# 1. Déterminer le nombre exact de restaurants.
# 1. Lister les différents quartiers représentés (*borough*) ainsi que les différents types de cuisine (*cuisine*).
# 1. Lister les noms des restaurants, ainsi que leur quartier, ne proposant que des soupes (*cuisine* égale à *Soups*).
# 1. Donner les nombre de restaurants ayant eu au moins une fois le *grade* (dans *grades*) `Z`.
# 1. Calculer le nombre de restaurants pour chaque quartier
# 1. Donner les cinq types de cuisine les plus présentes dans New-York (avec le plus de restaurants donc)
# 1. Pour chaque *grade* possible, donner le nombre d'évaluation avec ce grade, ainsi que le *score* moyen, minimum et maximum.
# 1. Créer un `DataFrame` contenant les restaurants en ligne et en colonne le score moyen obtenu pour chaque *grade* possible. Si un restaurant n'a pas eu d'évaluation d'un *grade*, nous aurons une valeur absente.

# %%
# Imports
import pymongo
import pprint
import pandas as pd

# %% [markdown]
# **1. Créer une connexion vers cette collection**

# %%
# Connection
con = pymongo.MongoClient("mongodb://193.51.82.104:2343/")
db = con.test

# %% [markdown]
# **2. Déterminer le nombre exact de restaurants.**

# %%
# db.count()
db.restaurants.estimated_document_count()
# Out:
# 25359

# %% [markdown]
# **3. Lister les différents quartiers représentés (borough) ainsi que les différents types de cuisine (cuisine).**

# %%
db.restaurants.distinct("borough")
# Out:
# ['Bronx', 'Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Missing']

# %%
db.restaurants.distinct("cuisine")
# Out:
# ['Bakery',
#  'Hamburgers',
#  'Irish',
#  'American',
#  'Jewish/Kosher',
#  'Delicatessen',
#  'Ice Cream, Gelato, Yogurt, Ices',
#  'Chinese',
#  'Chicken',
#  'Turkish',
#  'Caribbean',
#  'Donuts',
#  'Sandwiches/Salads/Mixed Buffet',
#  'Bagels/Pretzels',
#  'Continental',
#  'Pizza',
#  'Italian',
#  'Steak',
#  'Polish',
#  'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'German',
#  'French',
#  'Pizza/Italian',
#  'Mexican',
#  'Spanish',
#  'Café/Coffee/Tea',
#  'Tex-Mex',
#  'Pancakes/Waffles',
#  'Soul Food',
#  'Seafood',
#  'Hotdogs',
#  'Greek',
#  'Not Listed/Not Applicable',
#  'African',
#  'Japanese',
#  'Indian',
#  'Armenian',
#  'Thai',
#  'Chinese/Cuban',
#  'Mediterranean',
#  'Korean',
#  'Bottled beverages, including water, sodas, juices, etc.',
#  'Russian',
#  'Eastern European',
#  'Middle Eastern',
#  'Asian',
#  'Ethiopian',
#  'Vegetarian',
#  'Barbecue',
#  'Egyptian',
#  'English',
#  'Other',
#  'Sandwiches',
#  'Portuguese',
#  'Indonesian',
#  'Chinese/Japanese',
#  'Filipino',
#  'Juice, Smoothies, Fruit Salads',
#  'Brazilian',
#  'Afghan',
#  'Vietnamese/Cambodian/Malaysia',
#  'CafÃ©/Coffee/Tea',
#  'Soups & Sandwiches',
#  'Tapas',
#  'Moroccan',
#  'Pakistani',
#  'Peruvian',
#  'Bangladeshi',
#  'Czech',
#  'Salads',
#  'Creole',
#  'Fruits/Vegetables',
#  'Iranian',
#  'Cajun',
#  'Scandinavian',
#  'Polynesian',
#  'Soups',
#  'Australian',
#  'Hotdogs/Pretzels',
#  'Southwestern',
#  'Nuts/Confectionary',
#  'Hawaiian',
#  'Creole/Cajun',
#  'Californian',
#  'Chilean']

# %%
quartier_cuisine = db.restaurants.distinct("borough") + db.restaurants.distinct("cuisine")
quartier_cuisine
# Out:
# ['Bronx',
#  'Brooklyn',
#  'Manhattan',
#  'Queens',
#  'Staten Island',
#  'Missing',
#  'Bakery',
#  'Hamburgers',
#  'Irish',
#  'American',
#  'Jewish/Kosher',
#  'Delicatessen',
#  'Ice Cream, Gelato, Yogurt, Ices',
#  'Chinese',
#  'Chicken',
#  'Turkish',
#  'Caribbean',
#  'Donuts',
#  'Sandwiches/Salads/Mixed Buffet',
#  'Bagels/Pretzels',
#  'Continental',
#  'Pizza',
#  'Italian',
#  'Steak',
#  'Polish',
#  'Latin (Cuban, Dominican, Puerto Rican, South & Central American)',
#  'German',
#  'French',
#  'Pizza/Italian',
#  'Mexican',
#  'Spanish',
#  'Café/Coffee/Tea',
#  'Tex-Mex',
#  'Pancakes/Waffles',
#  'Soul Food',
#  'Seafood',
#  'Hotdogs',
#  'Greek',
#  'Not Listed/Not Applicable',
#  'African',
#  'Japanese',
#  'Indian',
#  'Armenian',
#  'Thai',
#  'Chinese/Cuban',
#  'Mediterranean',
#  'Korean',
#  'Bottled beverages, including water, sodas, juices, etc.',
#  'Russian',
#  'Eastern European',
#  'Middle Eastern',
#  'Asian',
#  'Ethiopian',
#  'Vegetarian',
#  'Barbecue',
#  'Egyptian',
#  'English',
#  'Other',
#  'Sandwiches',
#  'Portuguese',
#  'Indonesian',
#  'Chinese/Japanese',
#  'Filipino',
#  'Juice, Smoothies, Fruit Salads',
#  'Brazilian',
#  'Afghan',
#  'Vietnamese/Cambodian/Malaysia',
#  'CafÃ©/Coffee/Tea',
#  'Soups & Sandwiches',
#  'Tapas',
#  'Moroccan',
#  'Pakistani',
#  'Peruvian',
#  'Bangladeshi',
#  'Czech',
#  'Salads',
#  'Creole',
#  'Fruits/Vegetables',
#  'Iranian',
#  'Cajun',
#  'Scandinavian',
#  'Polynesian',
#  'Soups',
#  'Australian',
#  'Hotdogs/Pretzels',
#  'Southwestern',
#  'Nuts/Confectionary',
#  'Hawaiian',
#  'Creole/Cajun',
#  'Californian',
#  'Chilean']

# %% [markdown]
# **4. Lister les noms des restaurants, ainsi que leur quartier, ne proposant que des soupes (cuisine égale à Soups).**

# %%
def affiche(res):
    pprint.pprint(list(res))

# %%
res = db.restaurants.find(
    { "cuisine": "Soups" }, 
    { "_id": 0, 
     "name": 1, 
     "borough": 1}
)

affiche(res)
# Out:
# [{'borough': 'Manhattan', 'name': 'Wichcraft Express'},
#  {'borough': 'Staten Island', 'name': 'Original Soupman Of Staten Island'},
#  {'borough': 'Manhattan', 'name': 'The Original Soupman'},
#  {'borough': 'Manhattan', 'name': 'Peasant Stock'}]

# %% [markdown]
# **5. Donner les nombre de restaurants ayant eu au moins une fois le grade (dans grades) Z.**

# %%
res = db.restaurants.aggregate([
    {"$match": {"grades.grade": "Z"}},
    {"$group": {"_id": None, "nb": {"$sum": 1}}} 
])

affiche(res)
# Out:
# [{'_id': None, 'nb': 1337}]

# %% [markdown]
# **6. Calculer le nombre de restaurants pour chaque quartier**

# %%
res = db.restaurants.aggregate([
    {"$group": {"_id": "$borough", 
                "nb": {"$sum": 1}}} 
])

affiche(res)
# Out:
# [{'_id': 'Missing', 'nb': 51},
#  {'_id': 'Staten Island', 'nb': 969},
#  {'_id': 'Brooklyn', 'nb': 6086},
#  {'_id': 'Bronx', 'nb': 2338},
#  {'_id': 'Queens', 'nb': 5656},
#  {'_id': 'Manhattan', 'nb': 10259}]

# %% [markdown]
# **7. Donner les cinq types de cuisine les plus présentes dans New-York (avec le plus de restaurants donc)**

# %%
res = db.restaurants.aggregate([ 
    {"$group": {"_id": "$cuisine" , "nb" : {"$sum" : 1}}},
    {"$sort" : {"nb": -1}},
    {"$limit" : 5}
])
affiche(res)
# Out:
# [{'_id': 'American', 'nb': 6183},
#  {'_id': 'Chinese', 'nb': 2418},
#  {'_id': 'Café/Coffee/Tea', 'nb': 1214},
#  {'_id': 'Pizza', 'nb': 1163},
#  {'_id': 'Italian', 'nb': 1069}]

# %% [markdown]
# **8. Pour chaque grade possible, donner le nombre d'évaluation avec ce grade, ainsi que le score moyen, minimum et maximum**

# %%
res = db.restaurants.aggregate([
    {"$group" : { 
        "_id": "$grades.grade", 
        "nombre" : {"$sum" : 1 },
        "moyenne" : {"$avg" : "$grades.score"},
        "minimum" : {"$min" : "$grades.score"},
        "maximum" : {"$max" : "$grades.score"}
    }}
])
affiche(res)
# Out:
# [{'_id': ['Z', 'A', 'P'],
#   'maximum': [44, 13, 10],
#   'minimum': [30, 10, 2],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['C', 'P'],
#   'maximum': [43, 4],
#   'minimum': [30, 10],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['Z', 'P'],
#   'maximum': [25, 5],
#   'minimum': [3, 5],
#   'moyenne': None,
#   'nombre': 7},
#  {'_id': ['B', 'A', 'P'],
#   'maximum': [21, 13, 10],
#   'minimum': [14, 5, 4],
#   'moyenne': None,
#   'nombre': 4},
#  {'_id': ['C', 'B', 'P'],
#   'maximum': [36, 20, 5],
#   'minimum': [36, 20, 5],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'C', 'P'],
#   'maximum': [30, 10, 28, 17],
#   'minimum': [30, 10, 28, 17],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'P', 'C'],
#   'maximum': [13, 18, 2, 31],
#   'minimum': [13, 18, 2, 31],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'P', 'B', 'A'],
#   'maximum': [19, 13, 2, 16, 10],
#   'minimum': [19, 13, 2, 16, 10],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'C', 'A'],
#   'maximum': [34, 5, 13],
#   'minimum': [18, 4, 11],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['A', 'C', 'P'],
#   'maximum': [9, 2, 2],
#   'minimum': [0, 61, 2],
#   'moyenne': None,
#   'nombre': 4},
#  {'_id': ['C', 'B', 'A'],
#   'maximum': [36, 17, 12],
#   'minimum': [35, 19, 13],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['C', 'C'],
#   'maximum': [32, 39],
#   'minimum': [29, 0],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['B', 'P', 'A'],
#   'maximum': [26, 9, 12],
#   'minimum': [17, 4, 12],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['C', 'A', 'C', 'B'],
#   'maximum': [52, 10, 3, 25],
#   'minimum': [52, 10, 3, 25],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'A', 'P'],
#   'maximum': [35, 14, 9, 5],
#   'minimum': [35, 14, 9, 5],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'C'],
#   'maximum': [32, 25, 34],
#   'minimum': [25, 25, 3],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['B', 'C', 'B', 'A', 'P'],
#   'maximum': [20, 28, 19, 11, 13],
#   'minimum': [20, 28, 19, 11, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'C', 'A', 'B'],
#   'maximum': [20, 35, 10, 27],
#   'minimum': [20, 35, 10, 27],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'A', 'P'],
#   'maximum': [25, 13, 11, 4],
#   'minimum': [25, 10, 12, 14],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['C', 'C', 'B'],
#   'maximum': [30, 31, 19],
#   'minimum': [30, 31, 19],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'B', 'A', 'P'],
#   'maximum': [11, 22, 22, 7, 4],
#   'minimum': [11, 22, 22, 7, 4],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'P', 'A', 'B'],
#   'maximum': [19, 3, 12, 20],
#   'minimum': [19, 3, 12, 20],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'A', 'B', 'P'],
#   'maximum': [61, 12, 12, 24, 3],
#   'minimum': [24, 12, 11, 25, 11],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['B', 'B', 'P', 'A', 'A'],
#   'maximum': [16, 16, 3, 12, 12],
#   'minimum': [16, 16, 3, 12, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'P', 'B', 'B'],
#   'maximum': [24, 15, 0, 15, 23],
#   'minimum': [24, 15, 0, 15, 23],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'B', 'P'],
#   'maximum': [27, 22, 24, 5],
#   'minimum': [23, 14, 21, 15],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'A', 'P', 'A', 'P'],
#   'maximum': [9, 7, 5, 9, 6, 0],
#   'minimum': [9, 7, 5, 9, 6, 0],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'C', 'P', 'B', 'P'],
#   'maximum': [26, 20, 38, 2, 18, 9],
#   'minimum': [26, 20, 38, 2, 18, 9],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'A', 'A', 'C', 'P'],
#   'maximum': [36, 10, 7, 9, 2],
#   'minimum': [36, 10, 7, 9, 2],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'A', 'B', 'P'],
#   'maximum': [12, 39, 12, 27, 10],
#   'minimum': [12, 39, 12, 27, 10],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'C', 'B'],
#   'maximum': [23, 24, 42, 19],
#   'minimum': [21, 25, 34, 23],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['B', 'C', 'C', 'B'],
#   'maximum': [26, 2, 37, 27],
#   'minimum': [26, 2, 37, 27],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'P'],
#   'maximum': [13, 20, 5],
#   'minimum': [8, 22, 5],
#   'moyenne': None,
#   'nombre': 12},
#  {'_id': ['Z', 'A', 'C', 'C', 'P', 'C'],
#   'maximum': [4, 13, 29, 36, 9, 29],
#   'minimum': [4, 13, 29, 36, 9, 29],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'C', 'C', 'C'],
#   'maximum': [22, 33, 11, 3],
#   'minimum': [22, 33, 11, 3],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'C'],
#   'maximum': [62, 2, 34],
#   'minimum': [28, 10, 0],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['A', 'A', 'B', 'A', 'P'],
#   'maximum': [12, 12, 27, 11, 9],
#   'minimum': [11, 13, 27, 12, 4],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['B', 'A', 'A', 'B', 'A', 'P'],
#   'maximum': [15, 10, 11, 23, 12, 16],
#   'minimum': [15, 10, 11, 23, 12, 16],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'A', 'C', 'P', 'B', 'P'],
#   'maximum': [25, 12, 9, 37, 6, 18, 15],
#   'minimum': [25, 12, 9, 37, 6, 18, 15],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'P', 'C', 'A', 'P'],
#   'maximum': [5, 7, 4, 33, 9, 4],
#   'minimum': [5, 7, 4, 33, 9, 4],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'A', 'B'],
#   'maximum': [31, 17, 9, 26],
#   'minimum': [19, 22, 5, 22],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['C', 'B', 'A', 'B'],
#   'maximum': [47, 17, 12, 14],
#   'minimum': [35, 22, 13, 25],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['Z', 'C', 'A', 'B', 'P', 'A'],
#   'maximum': [20, 43, 9, 15, 11, 8],
#   'minimum': [20, 43, 9, 15, 11, 8],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'C', 'C', 'C', 'P'],
#   'maximum': [9, 7, 3, 12, 40, 4],
#   'minimum': [9, 7, 3, 12, 40, 4],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'C', 'C'],
#   'maximum': [15, 13, 35, 33],
#   'minimum': [14, 12, 39, 0],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['B', 'B', 'C', 'B'],
#   'maximum': [19, 18, 28, 18],
#   'minimum': [19, 18, 28, 18],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'B', 'C', 'B'],
#   'maximum': [60, 11, 14, 33, 19],
#   'minimum': [60, 11, 14, 33, 19],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'C'],
#   'maximum': [12, 3, 48],
#   'minimum': [10, 3, 37],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['B', 'C', 'B', 'B', 'A'],
#   'maximum': [23, 29, 25, 24, 12],
#   'minimum': [23, 29, 25, 24, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'P', 'A', 'B', 'B'],
#   'maximum': [9, 7, 2, 12, 23, 19],
#   'minimum': [9, 7, 2, 12, 23, 19],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'C', 'A', 'P', 'B'],
#   'maximum': [38, 33, 10, 2, 25],
#   'minimum': [38, 33, 10, 2, 25],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'C', 'A', 'B', 'A'],
#   'maximum': [30, 28, 13, 18, 12],
#   'minimum': [30, 28, 13, 18, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'P', 'A', 'P'],
#   'maximum': [2, 0, 2, 0, 0],
#   'minimum': [2, 0, 2, 0, 0],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C'],
#   'maximum': [69],
#   'minimum': [19],
#   'moyenne': None,
#   'nombre': 32},
#  {'_id': ['B', 'B', 'C', 'A', 'C', 'C'],
#   'maximum': [18, 27, 0, 5, 2, 4],
#   'minimum': [18, 27, 0, 5, 2, 4],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'A', 'C', 'B'],
#   'maximum': [18, 16, 10, 5, 17],
#   'minimum': [18, 16, 10, 5, 17],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'C'],
#   'maximum': [26, 34],
#   'minimum': [14, 48],
#   'moyenne': None,
#   'nombre': 14},
#  {'_id': ['A', 'C', 'B', 'B', 'A', 'C'],
#   'maximum': [13, 42, 18, 24, 10, 37],
#   'minimum': [13, 42, 18, 24, 10, 37],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'P'],
#   'maximum': [13, 13, 17, 12],
#   'minimum': [10, 3, 15, 2],
#   'moyenne': None,
#   'nombre': 5},
#  {'_id': ['Z', 'A', 'C', 'C', 'A'],
#   'maximum': [21, 9, 12, 5, 7],
#   'minimum': [21, 9, 12, 5, 7],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'A', 'C', 'B', 'B', 'P'],
#   'maximum': [12, 53, 11, 28, 19, 19, 3],
#   'minimum': [12, 53, 11, 28, 19, 19, 3],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'P', 'B', 'B', 'A'],
#   'maximum': [40, 5, 25, 22, 12],
#   'minimum': [40, 5, 25, 22, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'C', 'C', 'C', 'B'],
#   'maximum': [20, 25, 28, 28, 30, 24],
#   'minimum': [20, 25, 28, 28, 30, 24],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'C', 'C', 'B'],
#   'maximum': [14, 10, 56, 39, 15],
#   'minimum': [14, 10, 56, 39, 15],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'B', 'B', 'A', 'A'],
#   'maximum': [2, 18, 23, 9, 12],
#   'minimum': [2, 18, 23, 9, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'B', 'P', 'A', 'B'],
#   'maximum': [11, 61, 24, 9, 13, 14],
#   'minimum': [11, 61, 24, 9, 13, 14],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'A', 'B', 'P', 'A'],
#   'maximum': [19, 25, 12, 17, 11, 5],
#   'minimum': [19, 25, 12, 17, 11, 5],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'A', 'B', 'B', 'P'],
#   'maximum': [29, 22, 9, 26, 21, 0],
#   'minimum': [29, 22, 9, 26, 21, 0],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': [], 'maximum': [], 'minimum': [], 'moyenne': None, 'nombre': 738},
#  {'_id': ['A', 'A', 'P', 'B'],
#   'maximum': [13, 5, 3, 22],
#   'minimum': [7, 13, 7, 20],
#   'moyenne': None,
#   'nombre': 4},
#  {'_id': ['A', 'C', 'B', 'C', 'B', 'A'],
#   'maximum': [9, 46, 18, 32, 19, 10],
#   'minimum': [9, 46, 18, 32, 19, 10],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'B', 'B', 'A', 'B'],
#   'maximum': [13, 6, 25, 27, 25, 9, 27],
#   'minimum': [13, 6, 25, 27, 25, 9, 27],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'C', 'C', 'C', 'B'],
#   'maximum': [44, 9, 30, 5, 24],
#   'minimum': [44, 9, 30, 5, 24],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'B', 'B', 'C'],
#   'maximum': [13, 48, 24, 19, 36],
#   'minimum': [13, 48, 24, 19, 36],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'B', 'A', 'A', 'P', 'A'],
#   'maximum': [12, 20, 21, 9, 11, 2, 2],
#   'minimum': [12, 20, 21, 9, 11, 2, 2],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'P', 'B', 'A', 'C'],
#   'maximum': [7, 9, 11, 5, 21, 11, 49],
#   'minimum': [7, 9, 11, 5, 21, 11, 49],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'B', 'A', 'P'],
#   'maximum': [13, 12, 21, 13, 3],
#   'minimum': [13, 12, 21, 13, 3],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'P', 'B', 'A'],
#   'maximum': [17, 23, 3, 21, 13],
#   'minimum': [17, 23, 3, 21, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'B', 'A', 'P', 'B'],
#   'maximum': [19, 11, 15, 9, 5, 18],
#   'minimum': [19, 11, 15, 9, 5, 18],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'B', 'C', 'A'],
#   'maximum': [20, 10, 14, 9, 0],
#   'minimum': [20, 10, 14, 9, 0],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'C', 'B', 'A'],
#   'maximum': [15, 10, 28, 24, 11],
#   'minimum': [15, 10, 28, 24, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'A', 'P', 'B', 'A', 'B'],
#   'maximum': [11, 10, 5, 10, 13, 23, 7, 19],
#   'minimum': [11, 10, 5, 10, 13, 23, 7, 19],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'C', 'B', 'C', 'A'],
#   'maximum': [15, 43, 16, 31, 9],
#   'minimum': [15, 43, 16, 31, 9],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'A', 'B', 'A', 'B'],
#   'maximum': [12, 12, 17, 11, 24, 13, 18],
#   'minimum': [12, 12, 17, 11, 24, 13, 18],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'A', 'B', 'A', 'B', 'C'],
#   'maximum': [18, 9, 7, 24, 6, 26, 30],
#   'minimum': [18, 9, 7, 24, 6, 26, 30],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'P', 'A', 'B', 'B', 'B', 'B'],
#   'maximum': [14, 9, 10, 22, 18, 25, 14],
#   'minimum': [14, 9, 10, 22, 18, 25, 14],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'P', 'A', 'P', 'B', 'P', 'A'],
#   'maximum': [13, 17, 0, 13, 2, 17, 9, 13],
#   'minimum': [13, 17, 0, 13, 2, 17, 9, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'B', 'C', 'A'],
#   'maximum': [7, 49, 23, 46, 13],
#   'minimum': [7, 49, 23, 46, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'A', 'A', 'A', 'P'],
#   'maximum': [59, 9, 10, 7, 2],
#   'minimum': [59, 9, 10, 7, 2],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'B', 'A', 'B', 'P', 'B'],
#   'maximum': [26, 16, 20, 12, 26, 2, 19],
#   'minimum': [26, 16, 20, 12, 26, 2, 19],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'B', 'B', 'A', 'P', 'B'],
#   'maximum': [17, 9, 22, 21, 9, 4, 18],
#   'minimum': [17, 9, 22, 21, 9, 4, 18],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'B', 'A', 'B', 'A', 'A'],
#   'maximum': [21, 18, 25, 11, 17, 10, 10],
#   'minimum': [21, 18, 25, 11, 17, 10, 10],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'B', 'A', 'P', 'A'],
#   'maximum': [12, 22, 22, 11, 2, 0],
#   'minimum': [12, 22, 22, 11, 2, 0],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'B', 'B', 'B', 'C'],
#   'maximum': [31, 27, 26, 25, 27, 41],
#   'minimum': [31, 27, 26, 25, 27, 41],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'P', 'C', 'C', 'B'],
#   'maximum': [10, 14, 4, 30, 28, 25],
#   'minimum': [10, 14, 4, 30, 28, 25],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'A', 'C', 'C'],
#   'maximum': [23, 14, 11, 51, 28],
#   'minimum': [23, 14, 11, 51, 28],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'P', 'B', 'A', 'A', 'A', 'C'],
#   'maximum': [9, 23, 3, 21, 12, 12, 11, 40],
#   'minimum': [9, 23, 3, 21, 12, 12, 11, 40],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'C', 'B', 'P'],
#   'maximum': [9, 12, 4, 18, 14],
#   'minimum': [9, 12, 4, 18, 14],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'A', 'C', 'B', 'B'],
#   'maximum': [9, -1, 9, 28, 23, 23],
#   'minimum': [9, -1, 9, 28, 23, 23],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'B', 'A', 'B', 'C', 'B'],
#   'maximum': [22, 24, 17, 10, 25, 28, 23],
#   'minimum': [22, 24, 17, 10, 25, 28, 23],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'P'],
#   'maximum': [27, 2],
#   'minimum': [17, 3],
#   'moyenne': None,
#   'nombre': 5},
#  {'_id': ['A', 'B', 'B', 'P'],
#   'maximum': [13, 21, 26, 2],
#   'minimum': [7, 25, 19, 2],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['B', 'A', 'P', 'A', 'A', 'A', 'A'],
#   'maximum': [23, 13, 2, 2, 10, 12, 11],
#   'minimum': [23, 13, 2, 2, 10, 12, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'A', 'B', 'A', 'A'],
#   'maximum': [27, 17, 11, 21, 10, 6],
#   'minimum': [20, 25, 12, 22, 13, 2],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['Z', 'B', 'B', 'C', 'B', 'B', 'A'],
#   'maximum': [26, 19, 19, 40, 15, 15, 12],
#   'minimum': [26, 19, 19, 40, 15, 15, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'A', 'A', 'A', 'C'],
#   'maximum': [10, 9, 18, 13, 7, 7, 11],
#   'minimum': [10, 9, 18, 13, 7, 7, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'B', 'A', 'A', 'P', 'B', 'C'],
#   'maximum': [11, 24, 19, 11, 13, 0, 27, 32],
#   'minimum': [11, 24, 19, 11, 13, 0, 27, 32],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'A', 'A', 'C', 'B'],
#   'maximum': [21, 20, 2, 11, 12, 24],
#   'minimum': [21, 20, 2, 11, 12, 24],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'P', 'C', 'A', 'B', 'B'],
#   'maximum': [10, 7, 11, 9, 38, 12, 23, 17],
#   'minimum': [10, 7, 11, 9, 38, 12, 23, 17],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'B', 'A', 'A', 'B', 'A'],
#   'maximum': [23, 26, 20, 11, 10, 27, 7],
#   'minimum': [23, 26, 20, 11, 10, 27, 7],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'B', 'B', 'B', 'P', 'A'],
#   'maximum': [19, 20, 19, 15, 15, 0, 13],
#   'minimum': [19, 20, 19, 15, 15, 0, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'C', 'P', 'A'],
#   'maximum': [7, 8, 32, 13, 11],
#   'minimum': [7, 8, 32, 13, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'C', 'B', 'B', 'A', 'A'],
#   'maximum': [7, 27, 38, 24, 21, 10, 11],
#   'minimum': [7, 27, 38, 24, 21, 10, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'A', 'B', 'C', 'P', 'C'],
#   'maximum': [11, 21, 6, 18, 34, 11, 28],
#   'minimum': [11, 21, 6, 18, 34, 11, 28],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'C', 'B', 'A', 'B'],
#   'maximum': [11, 33, 43, 20, 13, 16],
#   'minimum': [11, 33, 43, 20, 13, 16],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'A', 'B', 'A', 'P'],
#   'maximum': [9, 13, 25, 12, 26, 11, 5],
#   'minimum': [7, 9, 17, 7, 19, 13, 4],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'B', 'B', 'A', 'B', 'C', 'B'],
#   'maximum': [7, 22, 20, 13, 16, 33, 17],
#   'minimum': [7, 22, 20, 13, 16, 33, 17],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'A', 'P', 'B', 'B', 'C'],
#   'maximum': [25, 20, 5, 6, 23, 14, 2],
#   'minimum': [25, 20, 5, 6, 23, 14, 2],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'P', 'A', 'A'],
#   'maximum': [-1, 0, 10, 12],
#   'minimum': [-1, 0, 10, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'A', 'B', 'B', 'A', 'A'],
#   'maximum': [12, 23, 10, 15, 15, 5, 11],
#   'minimum': [12, 23, 10, 15, 15, 5, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'B', 'C', 'C'],
#   'maximum': [9, 22, 15, 2, 46],
#   'minimum': [9, 22, 15, 2, 46],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'B', 'B', 'B', 'A', 'P'],
#   'maximum': [10, 22, 20, 25, 19, 9, 2],
#   'minimum': [10, 22, 20, 25, 19, 9, 2],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'P', 'C', 'A', 'B', 'A'],
#   'maximum': [10, 19, 3, 33, 6, 14, 8],
#   'minimum': [10, 19, 3, 33, 6, 14, 8],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'B', 'C', 'A', 'B', 'B'],
#   'maximum': [11, 26, 26, 35, 13, 26, 23],
#   'minimum': [11, 26, 26, 35, 13, 26, 23],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'B', 'P', 'A', 'B', 'B'],
#   'maximum': [15, 25, 21, 14, 13, 22, 19],
#   'minimum': [15, 25, 21, 14, 13, 22, 19],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'A', 'C', 'B', 'A'],
#   'maximum': [10, 10, 7, 11, 55, 27, 13],
#   'minimum': [10, 10, 7, 11, 55, 27, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z'],
#   'maximum': [61],
#   'minimum': [0],
#   'moyenne': None,
#   'nombre': 160},
#  {'_id': ['Z', 'A', 'B', 'A', 'B', 'B'],
#   'maximum': [24, 11, 16, 13, 19, 25],
#   'minimum': [18, 2, 18, 8, 27, 23],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['Z', 'A', 'A', 'P', 'B'],
#   'maximum': [42, 11, 10, 10, 14],
#   'minimum': [27, 10, 13, 4, 27],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'C', 'A', 'A', 'B', 'C'],
#   'maximum': [5, 13, 31, 12, 12, 14, 52],
#   'minimum': [5, 13, 31, 12, 12, 14, 52],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'C', 'A', 'B', 'C'],
#   'maximum': [11, 11, 82, 11, 19, 29],
#   'minimum': [11, 11, 82, 11, 19, 29],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'C', 'B', 'A'],
#   'maximum': [24, 40, 24, 13],
#   'minimum': [15, 28, 27, 11],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['A', 'B', 'C', 'C', 'A', 'B'],
#   'maximum': [13, 25, 12, 2, 5, 14],
#   'minimum': [13, 25, 12, 2, 5, 14],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'C', 'A', 'C', 'P', 'C'],
#   'maximum': [32, 11, 36, 9, 30, 9, 47],
#   'minimum': [32, 11, 36, 9, 30, 9, 47],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'B', 'B', 'A', 'B', 'A'],
#   'maximum': [15, 22, 22, 25, 10, 17, 11],
#   'minimum': [15, 22, 22, 25, 10, 17, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'B', 'B', 'A', 'A'],
#   'maximum': [9, 35, 17, 19, 13, 9],
#   'minimum': [9, 35, 17, 19, 13, 9],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'A', 'C', 'B', 'A'],
#   'maximum': [16, 24, 10, 37, 17, 11],
#   'minimum': [16, 24, 10, 37, 17, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'C', 'A'],
#   'maximum': [34, 17, 10, 4],
#   'minimum': [2, 24, 31, 11],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['Z', 'B', 'B', 'A', 'B', 'B'],
#   'maximum': [36, 17, 21, 13, 14, 15],
#   'minimum': [17, 19, 27, 7, 15, 22],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['A', 'A', 'A', 'A', 'A', 'A', 'A', 'P'],
#   'maximum': [7, 9, 5, 11, 4, 5, 8, 3],
#   'minimum': [7, 9, 5, 11, 4, 5, 8, 3],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'A', 'A', 'A', 'A', 'B'],
#   'maximum': [7, 3, 12, 10, 13, 11, 14],
#   'minimum': [7, 3, 12, 10, 13, 11, 14],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'P', 'C', 'P', 'B', 'B'],
#   'maximum': [21, 19, 17, 34, 4, 27, 23],
#   'minimum': [21, 19, 17, 34, 4, 27, 23],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'A', 'C', 'B', 'A'],
#   'maximum': [10, 9, 19, 12, 44, 19, 13],
#   'minimum': [10, 9, 19, 12, 44, 19, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'A', 'P', 'A'],
#   'maximum': [12, 25, 9, 6, 5],
#   'minimum': [11, 15, 12, 9, 11],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['Z', 'C', 'A', 'A', 'A', 'B', 'B'],
#   'maximum': [19, 29, 6, 10, 12, 21, 22],
#   'minimum': [19, 29, 6, 10, 12, 21, 22],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'C', 'A', 'A', 'B', 'B'],
#   'maximum': [11, 46, 4, 12, 13, 14, 27],
#   'minimum': [11, 46, 4, 12, 13, 14, 27],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'B', 'C', 'A'],
#   'maximum': [19, 27, 22, 37, 12],
#   'minimum': [19, 27, 22, 37, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'B', 'P', 'A', 'B', 'P'],
#   'maximum': [16, 19, 19, 9, 9, 19, 0],
#   'minimum': [16, 19, 19, 9, 9, 19, 0],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'B', 'C', 'A', 'B', 'C'],
#   'maximum': [14, 2, 14, 29, 10, 14, 46],
#   'minimum': [14, 2, 14, 29, 10, 14, 46],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'P', 'A', 'B', 'C'],
#   'maximum': [7, 10, 12, 9, 9, 16, 33],
#   'minimum': [7, 10, 12, 9, 9, 16, 33],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'C', 'P', 'C', 'B', 'P', 'A'],
#   'maximum': [7, 14, 8, 3, 42, 18, 2, 13],
#   'minimum': [7, 14, 8, 3, 42, 18, 2, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'C', 'A', 'B', 'B', 'A'],
#   'maximum': [21, 21, 37, 11, 22, 19, 11],
#   'minimum': [21, 21, 37, 11, 22, 19, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'C', 'A', 'C', 'B'],
#   'maximum': [41, 35, 12, 64, 22],
#   'minimum': [41, 35, 12, 64, 22],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'B', 'A', 'A', 'B', 'A'],
#   'maximum': [13, 24, 15, 12, 9, 26, 12],
#   'minimum': [13, 24, 15, 12, 9, 26, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'A', 'C', 'P', 'B'],
#   'maximum': [9, 9, 22, 13, 2, 9, 22],
#   'minimum': [9, 9, 22, 13, 2, 9, 22],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'A', 'A', 'A', 'C'],
#   'maximum': [55, 13, 12, 11, 49],
#   'minimum': [55, 13, 12, 11, 49],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'B', 'B', 'B', 'B', 'B'],
#   'maximum': [9, 24, 25, 26, 19, 18, 24],
#   'minimum': [9, 24, 25, 26, 19, 18, 24],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'A', 'B', 'P', 'A', 'A'],
#   'maximum': [11, 4, 9, 24, 10, 13, 12],
#   'minimum': [11, 4, 9, 24, 10, 13, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'B', 'A', 'A', 'B', 'B'],
#   'maximum': [13, 31, 27, 9, 13, 25, 16],
#   'minimum': [13, 31, 27, 9, 13, 25, 16],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'A', 'P', 'A'],
#   'maximum': [19, 6, 12, 5, 13],
#   'minimum': [14, 9, 11, 11, 13],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['Z', 'B', 'C', 'P', 'B', 'B', 'B'],
#   'maximum': [17, 14, 4, 7, 23, 18, 17],
#   'minimum': [17, 14, 4, 7, 23, 18, 17],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'A', 'B', 'B', 'P'],
#   'maximum': [22, 27, 12, 23, 27, 7],
#   'minimum': [22, 27, 12, 23, 27, 7],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'C', 'A', 'P', 'A', 'A'],
#   'maximum': [17, 53, 10, 2, 12, 12],
#   'minimum': [17, 53, 10, 2, 12, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'C', 'B', 'C', 'C', 'P', 'A', 'B'],
#   'maximum': [3, 11, 23, 42, 29, 9, 11, 26],
#   'minimum': [3, 11, 23, 42, 29, 9, 11, 26],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'A', 'A', 'B', 'B', 'A'],
#   'maximum': [11, 14, 12, 12, 17, 14, 11],
#   'minimum': [11, 14, 12, 12, 17, 14, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'P', 'A', 'A', 'B', 'C'],
#   'maximum': [12, 15, 5, 11, 7, 19, 7],
#   'minimum': [12, 15, 5, 11, 7, 19, 7],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'B', 'C', 'P', 'B', 'B'],
#   'maximum': [20, 11, 22, 10, 14, 17, 20],
#   'minimum': [20, 11, 22, 10, 14, 17, 20],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'P', 'B', 'A', 'A', 'B'],
#   'maximum': [14, 9, 19, 12, 11, 20],
#   'minimum': [14, 9, 19, 12, 11, 20],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'C', 'B', 'A', 'B', 'B'],
#   'maximum': [26, 11, 4, 21, 12, 14, 27],
#   'minimum': [26, 11, 4, 21, 12, 14, 27],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'P', 'B', 'B', 'B', 'C'],
#   'maximum': [7, 10, 12, 3, 17, 18, 23, 57],
#   'minimum': [7, 10, 12, 3, 17, 18, 23, 57],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'A', 'A', 'B', 'P'],
#   'maximum': [11, 24, 12, 12, 22, 2],
#   'minimum': [11, 24, 12, 12, 22, 2],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B'],
#   'maximum': [27, 26],
#   'minimum': [14, 18],
#   'moyenne': None,
#   'nombre': 49},
#  {'_id': ['A', 'B', 'A', 'B', 'B', 'C', 'C'],
#   'maximum': [10, 22, 11, 19, 26, 36, 3],
#   'minimum': [10, 22, 11, 19, 26, 36, 3],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'B', 'A', 'C', 'A', 'B'],
#   'maximum': [20, 8, 24, 13, 32, 13, 26],
#   'minimum': [20, 8, 24, 13, 32, 13, 26],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'C', 'B', 'C', 'C'],
#   'maximum': [12, 11, 51, 17, 30, 44],
#   'minimum': [12, 11, 51, 17, 30, 44],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'C', 'P', 'B', 'B', 'B'],
#   'maximum': [27, 27, 28, 4, 14, 26, 17],
#   'minimum': [27, 27, 28, 4, 14, 26, 17],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'B', 'A', 'A', 'P'],
#   'maximum': [13, 11, 22, 21, 13, 11, 11],
#   'minimum': [13, 11, 22, 21, 13, 11, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'C', 'A', 'P', 'C', 'B'],
#   'maximum': [9, 12, 42, 10, 3, 54, 22],
#   'minimum': [9, 12, 42, 10, 3, 54, 22],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'A', 'B'],
#   'maximum': [75, 5, 18],
#   'minimum': [0, 10, 20],
#   'moyenne': None,
#   'nombre': 8},
#  {'_id': ['Z', 'B', 'B', 'C', 'C', 'A'],
#   'maximum': [32, 21, 25, 32, 35, 12],
#   'minimum': [32, 21, 25, 32, 35, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'B', 'B', 'C', 'A'],
#   'maximum': [7, 9, 21, 18, 24, 40, 2],
#   'minimum': [7, 9, 21, 18, 24, 40, 2],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'P', 'B', 'C'],
#   'maximum': [10, 10, 0, 18, 30],
#   'minimum': [10, 10, 0, 18, 30],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'C', 'A', 'P', 'A'],
#   'maximum': [25, 12, 38, 12, 4, 12],
#   'minimum': [25, 12, 38, 12, 4, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'B', 'C', 'B', 'A'],
#   'maximum': [22, 18, 26, 65, 20, 12],
#   'minimum': [22, 18, 26, 65, 20, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'P', 'A', 'C', 'A', 'A', 'P'],
#   'maximum': [10, 9, 11, 0, 7, 31, 10, 7, 0],
#   'minimum': [10, 9, 11, 0, 7, 31, 10, 7, 0],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'B', 'B', 'P', 'B', 'B', 'B'],
#   'maximum': [16, 12, 20, 19, 2, 26, 25, 24],
#   'minimum': [16, 12, 20, 19, 2, 26, 25, 24],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'P', 'B', 'B', 'A', 'B', 'B'],
#   'maximum': [12, 2, 10, 18, 24, 8, 24, 25],
#   'minimum': [12, 2, 10, 18, 24, 8, 24, 25],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'A', 'C', 'B', 'A', 'P'],
#   'maximum': [16, 21, 12, 29, 18, 12, 15],
#   'minimum': [16, 21, 12, 29, 18, 12, 15],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'A', 'A', 'P', 'A', 'C'],
#   'maximum': [11, 12, 9, 9, 11, 5, 10, 3],
#   'minimum': [11, 12, 9, 9, 11, 5, 10, 3],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'A', 'B', 'C', 'C', 'A'],
#   'maximum': [13, 15, 9, 22, 30, 30, 13],
#   'minimum': [13, 15, 9, 22, 30, 30, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'C', 'A', 'B'],
#   'maximum': [13, 33, 3, 5, 14],
#   'minimum': [11, 34, 59, 12, 26],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['Z', 'A', 'C', 'A', 'B'],
#   'maximum': [36, 12, 36, 12, 14],
#   'minimum': [2, 13, 38, 10, 19],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['B', 'A', 'C', 'C', 'A'],
#   'maximum': [14, 12, 34, 38, 13],
#   'minimum': [14, 12, 34, 38, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'A', 'P', 'A', 'A'],
#   'maximum': [9, 10, 19, 5, 2, 11, 12],
#   'minimum': [9, 10, 19, 5, 2, 11, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'C', 'C', 'B', 'C'],
#   'maximum': [27, 11, 29, 66, 15, 31],
#   'minimum': [27, 11, 29, 66, 15, 31],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'B', 'P', 'C', 'A'],
#   'maximum': [20, 12, 19, 4, 40, 10],
#   'minimum': [20, 12, 19, 4, 40, 10],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'B', 'A', 'B', 'B'],
#   'maximum': [6, 3, 21, 22, 13, 16, 23],
#   'minimum': [6, 3, 21, 22, 13, 16, 23],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'A', 'B', 'P', 'B', 'B', 'B'],
#   'maximum': [5, -1, 2, 15, 2, 18, 20, 23],
#   'minimum': [5, -1, 2, 15, 2, 18, 20, 23],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'A', 'C', 'C', 'A'],
#   'maximum': [11, 12, 13, 12, 51, 61, 10],
#   'minimum': [11, 12, 13, 12, 51, 61, 10],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'B', 'B', 'A', 'B'],
#   'maximum': [27, 9, 21, 17, 11, 19],
#   'minimum': [27, 9, 21, 17, 11, 19],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'B', 'B', 'C', 'B'],
#   'maximum': [17, 10, 27, 25, 43, 18],
#   'minimum': [17, 10, 27, 25, 43, 18],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'C', 'A', 'A', 'B'],
#   'maximum': [17, 10, 34, 13, 9, 17],
#   'minimum': [17, 10, 34, 13, 9, 17],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'P', 'B', 'A', 'P', 'C', 'B', 'B'],
#   'maximum': [9, 4, 14, 12, 9, 48, 16, 24],
#   'minimum': [9, 4, 14, 12, 9, 48, 16, 24],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'C', 'B', 'A', 'C', 'A'],
#   'maximum': [40, 31, 26, 10, 76, 5],
#   'minimum': [40, 31, 26, 10, 76, 5],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'C', 'B', 'B', 'A', 'A'],
#   'maximum': [15, 19, 2, 23, 17, 10, 10],
#   'minimum': [15, 19, 2, 23, 17, 10, 10],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'C', 'P', 'B'],
#   'maximum': [13, 12, 5, 28, 3, 14],
#   'minimum': [13, 12, 5, 28, 3, 14],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'B', 'C', 'A', 'B'],
#   'maximum': [12, 19, 17, 37, 10, 25],
#   'minimum': [12, 19, 17, 37, 10, 25],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'P', 'A', 'A', 'B', 'P', 'A'],
#   'maximum': [12, 12, 10, 10, 17, 13, 4],
#   'minimum': [12, 12, 10, 10, 17, 13, 4],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'A', 'B', 'B', 'C'],
#   'maximum': [12, 13, 9, 13, 19, 22, 48],
#   'minimum': [12, 13, 9, 13, 19, 22, 48],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'C', 'P', 'A', 'P', 'C', 'B'],
#   'maximum': [11, 30, 9, 12, 3, 44, 14],
#   'minimum': [11, 30, 9, 12, 3, 44, 14],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'C', 'B', 'A', 'B', 'B'],
#   'maximum': [18, 43, 21, 13, 24, 22],
#   'minimum': [16, 48, 15, 11, 17, 27],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'A', 'C', 'P', 'B', 'A'],
#   'maximum': [12, 7, 13, 34, 2, 20, 8],
#   'minimum': [12, 7, 13, 34, 2, 20, 8],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'B', 'A', 'B', 'A', 'B'],
#   'maximum': [19, 7, 26, 11, 25, 13, 24],
#   'minimum': [19, 7, 26, 11, 25, 13, 24],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'C', 'B', 'B', 'A'],
#   'maximum': [26, 20, 51, 17, 15, 13],
#   'minimum': [26, 20, 51, 17, 15, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'A', 'A', 'A', 'B', 'A'],
#   'maximum': [5, 12, 10, 7, 11, 10, 18, 5],
#   'minimum': [5, 12, 10, 7, 11, 10, 18, 5],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'C', 'B', 'A', 'A', 'B'],
#   'maximum': [17, 28, 27, 10, 5, 20],
#   'minimum': [17, 28, 27, 10, 5, 20],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'C', 'B', 'B', 'B', 'P'],
#   'maximum': [19, 5, 21, 16, 22, 12],
#   'minimum': [19, 5, 21, 16, 22, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'P', 'C', 'A', 'A', 'B'],
#   'maximum': [21, 3, 12, 11, 5, 20],
#   'minimum': [21, 3, 12, 11, 5, 20],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'P', 'A', 'A', 'A', 'C', 'B', 'A'],
#   'maximum': [10, 3, 12, 12, 11, 31, 18, 12],
#   'minimum': [10, 3, 12, 12, 11, 31, 18, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'C', 'A', 'A', 'A', 'A'],
#   'maximum': [27, 7, 43, 12, 10, 12, 12],
#   'minimum': [27, 7, 43, 12, 10, 12, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'A', 'C', 'C'],
#   'maximum': [13, 9, 19, 11, 34, 30],
#   'minimum': [13, 9, 17, 5, 34, 46],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'P', 'A', 'A', 'A', 'A', 'B'],
#   'maximum': [11, 10, 2, 7, 12, 9, 4, 16],
#   'minimum': [11, 10, 2, 7, 12, 9, 4, 16],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'A', 'C', 'A', 'A'],
#   'maximum': [33, 11, 2, 35, 3, 12],
#   'minimum': [29, 10, 13, 2, 5, 11],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'B', 'A', 'C', 'B', 'P'],
#   'maximum': [12, 21, 13, 7, 20, 13],
#   'minimum': [12, 21, 13, 7, 20, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'B', 'C', 'A', 'A'],
#   'maximum': [11, 10, 26, 16, 32, 9, 11],
#   'minimum': [11, 10, 26, 16, 32, 9, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'B', 'A', 'C', 'B'],
#   'maximum': [17, 24, 14, 9, 28, 16],
#   'minimum': [17, 24, 14, 9, 28, 16],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'A', 'P', 'A', 'A'],
#   'maximum': [38, 12, 6, 10, 6],
#   'minimum': [38, 9, 2, 9, 9],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'C', 'C', 'A', 'A'],
#   'maximum': [10, 13, 42, 4, 13, 9],
#   'minimum': [10, 13, 42, 4, 13, 9],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'P', 'B', 'A', 'B', 'A'],
#   'maximum': [17, 15, 0, 19, 12, 18, 13],
#   'minimum': [17, 15, 0, 19, 12, 18, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'B', 'P', 'B', 'B', 'B'],
#   'maximum': [13, 16, 26, 4, 24, 16, 17],
#   'minimum': [13, 16, 26, 4, 24, 16, 17],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'B', 'P', 'A', 'A', 'B'],
#   'maximum': [37, 11, 15, 12, 11, 10, 26],
#   'minimum': [37, 11, 15, 12, 11, 10, 26],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'C', 'P', 'A', 'A'],
#   'maximum': [12, 11, 3, 31, 2, 11, 10],
#   'minimum': [12, 11, 3, 31, 2, 11, 10],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'P', 'A', 'A', 'A', 'A', 'B'],
#   'maximum': [13, 23, 5, 11, 10, 10, 10, 22],
#   'minimum': [13, 23, 5, 11, 10, 10, 10, 22],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'A', 'C', 'A'],
#   'maximum': [43, 11, 5, 37, 13],
#   'minimum': [10, 13, 10, 30, 9],
#   'moyenne': None,
#   'nombre': 4},
#  {'_id': ['Z', 'A', 'B', 'P', 'C', 'B', 'A'],
#   'maximum': [43, 7, 16, 0, 30, 25, 7],
#   'minimum': [43, 7, 16, 0, 30, 25, 7],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'B', 'B', 'B', 'B', 'A'],
#   'maximum': [17, 9, 20, 21, 18, 15, 6],
#   'minimum': [17, 9, 20, 21, 18, 15, 6],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'P', 'B', 'A'],
#   'maximum': [9, 5, 17, 7],
#   'minimum': [9, 2, 21, 13],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['B', 'A', 'A', 'A', 'C', 'A', 'A'],
#   'maximum': [26, 12, 3, 9, 37, 12, 9],
#   'minimum': [26, 12, 3, 9, 37, 12, 9],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'A', 'P', 'B', 'A', 'B'],
#   'maximum': [17, 12, 4, 5, 15, 10, 20],
#   'minimum': [17, 12, 4, 5, 15, 10, 20],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'A', 'P', 'C', 'A', 'A'],
#   'maximum': [5, 12, 14, 0, 2, 4, 13, 3],
#   'minimum': [5, 12, 14, 0, 2, 4, 13, 3],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'A', 'P', 'A', 'A', 'A'],
#   'maximum': [22, 0, 10, 9, 7, 11, 12],
#   'minimum': [20, 7, 10, 5, 12, 11, 10],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['B', 'B', 'A', 'C', 'B', 'A', 'B'],
#   'maximum': [18, 22, 9, 4, 14, 10, 27],
#   'minimum': [18, 22, 9, 4, 14, 10, 27],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'A', 'A', 'A', 'C', 'P'],
#   'maximum': [2, 33, 11, 10, 8, 34, 2],
#   'minimum': [2, 33, 11, 10, 8, 34, 2],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'B', 'A', 'P', 'C', 'C', 'B'],
#   'maximum': [66, 26, 12, 10, 35, 7, 25],
#   'minimum': [66, 26, 12, 10, 35, 7, 25],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'C', 'B', 'P'],
#   'maximum': [5, 10, 7, 3, 15, 11],
#   'minimum': [5, 10, 7, 3, 15, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'P', 'A', 'A', 'A'],
#   'maximum': [13, 5, 4, 12, 13],
#   'minimum': [2, 2, 7, 10, 13],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'B', 'A', 'P', 'A', 'A', 'A'],
#   'maximum': [13, 22, 13, 5, 12, 9, 12],
#   'minimum': [12, 15, 7, 5, 11, 10, 12],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'B', 'A', 'B', 'P', 'B', 'A', 'C'],
#   'maximum': [13, 15, 8, 17, 5, 22, 3, 35],
#   'minimum': [13, 15, 8, 17, 5, 22, 3, 35],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'A', 'P', 'A', 'A', 'C'],
#   'maximum': [10, 12, 11, 12, 5, 13, 9, 28],
#   'minimum': [10, 12, 11, 12, 5, 13, 9, 28],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'B', 'A', 'C'],
#   'maximum': [13, 12, 25, 19, 8, 28],
#   'minimum': [7, 12, 21, 18, 11, 98],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['A', 'A', 'C', 'A', 'B', 'B', 'C'],
#   'maximum': [0, 11, 3, 12, 26, 22, 53],
#   'minimum': [0, 11, 3, 12, 26, 22, 53],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'A', 'B', 'A', 'A', 'A'],
#   'maximum': [13, 29, 9, 14, 13, 11, 10],
#   'minimum': [11, 33, 10, 25, 10, 5, 6],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'B', 'A', 'B', 'C'],
#   'maximum': [13, 24, 12, 18, 46],
#   'minimum': [11, 17, 10, 15, 37],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'C', 'P', 'B', 'B', 'C'],
#   'maximum': [11, 12, 35, 2, 23, 22, 56],
#   'minimum': [11, 12, 35, 2, 23, 22, 56],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'P', 'B', 'A'],
#   'maximum': [7, 16, 11, 18, 7],
#   'minimum': [2, 24, 2, 25, 12],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['B', 'A', 'B', 'B', 'A', 'C'],
#   'maximum': [19, 10, 24, 16, 10, 2],
#   'minimum': [19, 10, 24, 16, 10, 2],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'C', 'B', 'B', 'C', 'B', 'B'],
#   'maximum': [34, 35, 19, 25, 11, 26, 14],
#   'minimum': [34, 35, 19, 25, 11, 26, 14],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'A', 'C', 'A', 'C', 'C'],
#   'maximum': [11, 22, 4, 65, 12, 34, 34],
#   'minimum': [11, 22, 4, 65, 12, 34, 34],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'B', 'B', 'B', 'A', 'C'],
#   'maximum': [22, 9, 15, 23, 19, 13, 32],
#   'minimum': [22, 9, 15, 23, 19, 13, 32],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'C', 'C', 'B', 'B', 'C', 'C'],
#   'maximum': [18, 30, 41, 21, 24, 42, 29],
#   'minimum': [18, 30, 41, 21, 24, 42, 29],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'B', 'P', 'C', 'A', 'B', 'B'],
#   'maximum': [17, 23, 26, 2, 31, 11, 24, 25],
#   'minimum': [17, 23, 26, 2, 31, 11, 24, 25],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'A', 'B', 'B', 'B', 'C'],
#   'maximum': [19, 22, 5, 18, 14, 27, 46],
#   'minimum': [19, 22, 5, 18, 14, 27, 46],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'A', 'A', 'P', 'B', 'A'],
#   'maximum': [31, 10, 7, 10, 11, 18, 7],
#   'minimum': [31, 10, 7, 10, 11, 18, 7],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'A', 'P', 'C', 'B'],
#   'maximum': [19, 11, 9, 9, 34, 17],
#   'minimum': [19, 11, 9, 9, 34, 17],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'B', 'C', 'A', 'B'],
#   'maximum': [25, 19, 17, 5, 6, 19],
#   'minimum': [22, 22, 19, 28, 13, 23],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['Z', 'B', 'P'],
#   'maximum': [51, 16, 2],
#   'minimum': [51, 16, 2],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'P', 'B', 'B', 'P', 'B'],
#   'maximum': [11, 9, 15, 21, 22, 6, 20],
#   'minimum': [11, 9, 15, 21, 22, 6, 20],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'C', 'A', 'B', 'C'],
#   'maximum': [10, 10, 11, 2, 8, 27, 3],
#   'minimum': [10, 10, 11, 2, 8, 27, 3],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'P', 'C'],
#   'maximum': [11, 11, 7, 2, 10],
#   'minimum': [11, 11, 7, 2, 10],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'B', 'A', 'A', 'B', 'A'],
#   'maximum': [10, 12, 17, 23, 10, 10, 26, 12],
#   'minimum': [10, 12, 17, 23, 10, 10, 26, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'A', 'A', 'P', 'A', 'B'],
#   'maximum': [27, 9, 10, 12, 11, 13, 22],
#   'minimum': [27, 9, 10, 12, 11, 13, 22],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'P', 'A', 'C', 'B'],
#   'maximum': [8, 5, 0, 10, 28, 26],
#   'minimum': [8, 5, 0, 10, 28, 26],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'A', 'B', 'C'],
#   'maximum': [25, 8, 9, 25, 37],
#   'minimum': [19, 7, 12, 19, 6],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['A', 'A', 'B', 'P', 'B', 'P', 'A', 'C'],
#   'maximum': [12, 13, 18, 5, 24, 10, 12, 31],
#   'minimum': [12, 13, 18, 5, 24, 10, 12, 31],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'P', 'A', 'A', 'A', 'A', 'A'],
#   'maximum': [17, 9, 10, 8, 10, 13, 12],
#   'minimum': [17, 9, 10, 8, 10, 13, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'A', 'C', 'B', 'A'],
#   'maximum': [13, 2, 10, 5, 20, 7],
#   'minimum': [13, 2, 10, 5, 20, 7],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'P', 'A', 'B', 'A'],
#   'maximum': [12, 12, 9, 3, 11, 25, 12],
#   'minimum': [9, 10, 10, 5, 10, 23, 7],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['C', 'C', 'A', 'C', 'A'],
#   'maximum': [29, 12, 9, 41, 9],
#   'minimum': [29, 12, 9, 41, 9],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'P', 'A', 'A', 'A', 'B', 'A'],
#   'maximum': [11, 11, 5, 7, 11, 8, 20, 11],
#   'minimum': [11, 11, 5, 7, 11, 8, 20, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'A', 'P', 'B', 'A'],
#   'maximum': [31, 13, 9, 3, 20, 9],
#   'minimum': [31, 13, 9, 3, 20, 9],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'P', 'B', 'A', 'B', 'A'],
#   'maximum': [7, 47, 11, 17, 12, 17, 13],
#   'minimum': [7, 47, 11, 17, 12, 17, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'B', 'B', 'C'],
#   'maximum': [18, 12, 24, 18, 81],
#   'minimum': [18, 12, 24, 18, 81],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'C', 'B', 'B', 'B'],
#   'maximum': [32, 13, 49, 25, 23, 18],
#   'minimum': [32, 13, 49, 25, 23, 18],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'A', 'B', 'A', 'B'],
#   'maximum': [20, 10, 13, 25, 13, 25],
#   'minimum': [15, 12, 13, 14, 7, 27],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['B', 'B', 'A', 'C', 'B', 'C'],
#   'maximum': [18, 17, 10, 2, 25, 31],
#   'minimum': [14, 15, 12, 46, 17, 17],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'B', 'C', 'B', 'B', 'P', 'A', 'C'],
#   'maximum': [6, 14, 56, 26, 19, 0, 13, 34],
#   'minimum': [6, 14, 56, 26, 19, 0, 13, 34],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'C', 'B', 'A'],
#   'maximum': [7, 30, 53, 17, 12],
#   'minimum': [7, 30, 53, 17, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'A', 'C', 'B'],
#   'maximum': [16, 11, 11, 52, 23],
#   'minimum': [16, 11, 11, 52, 23],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'A', 'C', 'P', 'A'],
#   'maximum': [13, 22, 8, 29, 4, 3],
#   'minimum': [13, 22, 8, 29, 4, 3],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'P', 'B', 'B', 'B'],
#   'maximum': [12, 9, 22, 4, 14, 20, 21],
#   'minimum': [12, 9, 22, 4, 14, 20, 21],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'C', 'P', 'B', 'B', 'B'],
#   'maximum': [10, 9, 3, 8, 23, 21, 25],
#   'minimum': [10, 9, 3, 8, 23, 21, 25],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'B', 'B', 'B', 'A', 'B', 'C'],
#   'maximum': [10, 0, 24, 22, 15, 13, 18, 20],
#   'minimum': [10, 0, 24, 22, 15, 13, 18, 20],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'A', 'A', 'A', 'B', 'A'],
#   'maximum': [17, 27, 13, 7, 7, 20, 5],
#   'minimum': [17, 27, 13, 7, 7, 20, 5],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'B', 'A', 'C', 'C'],
#   'maximum': [41, 13, 27, 9, 0, 2],
#   'minimum': [35, 13, 23, 7, 2, 42],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'C', 'C', 'B', 'B'],
#   'maximum': [12, 10, 4, 42, 27, 15],
#   'minimum': [12, 10, 4, 42, 27, 15],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'B', 'P', 'B', 'B', 'A'],
#   'maximum': [32, 12, 16, 10, 23, 22, 13],
#   'minimum': [32, 12, 16, 10, 23, 22, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'A', 'A', 'A', 'P'],
#   'maximum': [8, 11, 18, 12, 10, 10, 2],
#   'minimum': [8, 11, 18, 12, 10, 10, 2],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'A', 'A', 'C', 'A'],
#   'maximum': [23, 7, 12, 10, 28, 11],
#   'minimum': [21, 11, 11, 12, 42, 11],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['Z', 'B', 'P', 'B', 'A', 'P', 'A', 'B'],
#   'maximum': [40, 14, 2, 24, 10, 3, 13, 27],
#   'minimum': [40, 14, 2, 24, 10, 3, 13, 27],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'A', 'A', 'A', 'B', 'C'],
#   'maximum': [11, 17, 11, 10, 9, 22, 36],
#   'minimum': [11, 17, 11, 10, 9, 22, 36],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'A', 'B', 'B', 'B', 'B'],
#   'maximum': [51, 7, 18, 14, 26, 24],
#   'minimum': [51, 7, 18, 14, 26, 24],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'A', 'P', 'A'],
#   'maximum': [9, 45, 10, 2, 13],
#   'minimum': [9, 45, 10, 2, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'A', 'A', 'C'],
#   'maximum': [35, 13, 13, 28],
#   'minimum': [35, 13, 13, 28],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'P', 'B', 'C'],
#   'maximum': [6, 8, 9, 6, 26, 29],
#   'minimum': [6, 8, 9, 6, 26, 29],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'B', 'A', 'B', 'C', 'A'],
#   'maximum': [18, 20, 14, 12, 24, 28, 11],
#   'minimum': [18, 20, 14, 12, 24, 28, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'B', 'B', 'B', 'B', 'C'],
#   'maximum': [11, 12, 17, 20, 18, 24, 45],
#   'minimum': [10, 3, 24, 21, 15, 27, 9],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'A', 'C', 'A', 'P', 'C'],
#   'maximum': [13, 12, 9, 8, 6, 0, 30],
#   'minimum': [13, 12, 9, 8, 6, 0, 30],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'A', 'B', 'A', 'B', 'B', 'C'],
#   'maximum': [34, 9, 27, 7, 27, 21, 43],
#   'minimum': [34, 9, 27, 7, 27, 21, 43],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'B', 'A', 'C', 'A'],
#   'maximum': [13, 6, 18, 7, 2, 8],
#   'minimum': [13, 6, 18, 7, 2, 8],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'C', 'P', 'A'],
#   'maximum': [9, 24, 39, 3, 10],
#   'minimum': [9, 24, 39, 3, 10],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'C', 'B', 'A'],
#   'maximum': [27, 10, 28, 15, 8],
#   'minimum': [27, 10, 28, 15, 8],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'C', 'C', 'B', 'A'],
#   'maximum': [13, 9, 10, 0, 4, 19, 12],
#   'minimum': [13, 9, 10, 0, 4, 19, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'P', 'A', 'A', 'A'],
#   'maximum': [21, 11, 0, 13, 9, 11],
#   'minimum': [18, 8, 2, 11, 7, 7],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['Z', 'B', 'A', 'C', 'A', 'A'],
#   'maximum': [17, 22, 10, 32, 7, 11],
#   'minimum': [17, 22, 10, 32, 7, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'P', 'A', 'A', 'A'],
#   'maximum': [27, 11, 11, 5, 11, 13],
#   'minimum': [27, 11, 11, 5, 11, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'A', 'B', 'A', 'B', 'A'],
#   'maximum': [13, 2, 5, 18, 10, 22, 11],
#   'minimum': [9, 48, 9, 21, 12, 14, 13],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['B', 'B', 'B', 'B', 'B', 'B'],
#   'maximum': [21, 19, 20, 24, 25, 14],
#   'minimum': [19, 26, 26, 22, 23, 27],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['B', 'A', 'A', 'B', 'P'],
#   'maximum': [27, 13, 12, 15, 0],
#   'minimum': [16, 9, 6, 22, 5],
#   'moyenne': None,
#   'nombre': 4},
#  {'_id': ['A', 'B', 'B', 'A', 'A', 'A', 'A', 'C'],
#   'maximum': [12, 17, 23, 12, 10, 8, 13, 2],
#   'minimum': [12, 17, 23, 12, 10, 8, 13, 2],
# ...
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'B', 'A', 'A', 'A'],
#   'maximum': [25, 22, 23, 11, 12, 8],
#   'minimum': [18, 17, 14, 2, 10, 12],
#   'moyenne': None,
#   'nombre': 5},
#  {'_id': ['B', 'B', 'B', 'B', 'C'],
#   'maximum': [20, 16, 26, 26, 46],
#   'minimum': [16, 21, 21, 18, 31],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['A', 'A', 'B', 'C', 'A', 'A', 'A'],
#   'maximum': [5, 12, 20, 53, 13, 10, 12],
#   'minimum': [5, 12, 20, 53, 13, 10, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'P', 'A', 'A'],
#   'maximum': [22, 13, 9, 13, 13],
#   'minimum': [22, 13, 9, 13, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'C', 'B', 'A', 'B'],
#   'maximum': [12, 10, 39, 16, 11, 25],
#   'minimum': [10, 13, 4, 17, 12, 16],
#   'moyenne': None,
#   'nombre': 4},
#  {'_id': ['A', 'C', 'A', 'B', 'A', 'B'],
#   'maximum': [10, 58, 7, 16, 12, 23],
#   'minimum': [10, 58, 7, 16, 12, 23],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'B', 'A', 'B', 'A', 'C'],
#   'maximum': [24, 12, 21, 13, 27, 9, 21],
#   'minimum': [24, 12, 21, 13, 27, 9, 21],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'A', 'C', 'A', 'B', 'A'],
#   'maximum': [18, 12, 9, 32, 10, 27, 13],
#   'minimum': [18, 12, 9, 32, 10, 27, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'A', 'P', 'C', 'A', 'P', 'B', 'B'],
#   'maximum': [12, 21, 7, 5, 10, 13, 17, 19, 25],
#   'minimum': [12, 21, 7, 5, 10, 13, 17, 19, 25],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'C', 'B', 'P', 'B', 'C', 'C'],
#   'maximum': [19, 35, 21, 9, 27, 35, 47],
#   'minimum': [19, 35, 21, 9, 27, 35, 47],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'C'],
#   'maximum': [26, 23, 70],
#   'minimum': [14, 16, 30],
#   'moyenne': None,
#   'nombre': 4},
#  {'_id': ['A', 'B', 'C', 'C', 'C', 'A'],
#   'maximum': [13, 25, 73, 33, 10, 0],
#   'minimum': [13, 25, 73, 33, 10, 0],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'B', 'A', 'A', 'B'],
#   'maximum': [26, 26, 23, 7, 13, 25],
#   'minimum': [22, 23, 20, 13, 5, 17],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'C', 'A', 'A', 'P', 'A'],
#   'maximum': [12, 13, 41, 13, 11, 2, 4],
#   'minimum': [12, 13, 41, 13, 11, 2, 4],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'P', 'A', 'B', 'B'],
#   'maximum': [10, 12, 12, 5, 11, 22, 24],
#   'minimum': [10, 12, 12, 5, 11, 22, 24],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'B'],
#   'maximum': [26, 19, 18],
#   'minimum': [14, 19, 14],
#   'moyenne': None,
#   'nombre': 13},
#  {'_id': ['B', 'C', 'A', 'P', 'A'],
#   'maximum': [15, 9, 5, 3, 12],
#   'minimum': [15, 9, 5, 3, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'B', 'A', 'C', 'B'],
#   'maximum': [12, 7, 21, 27, 13, 19, 21],
#   'minimum': [12, 7, 21, 27, 13, 19, 21],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'A', 'B', 'A', 'C'],
#   'maximum': [21, 18, 10, 19, 7, 33],
#   'minimum': [21, 18, 10, 19, 7, 33],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'C', 'A', 'B', 'A', 'B'],
#   'maximum': [12, 8, 7, 7, 27, 11, 19],
#   'minimum': [7, 11, 5, 5, 25, 9, 18],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'B', 'C', 'B', 'B'],
#   'maximum': [12, 12, 17, 38, 15, 23],
#   'minimum': [5, 5, 18, 38, 22, 24],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'A', 'A', 'A', 'B', 'P', 'B'],
#   'maximum': [13, 10, 13, 13, 7, 19, 2, 16],
#   'minimum': [13, 10, 13, 13, 7, 19, 2, 16],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'C', 'A', 'B', 'C', 'B'],
#   'maximum': [15, 33, 7, 18, 38, 23],
#   'minimum': [15, 33, 7, 18, 38, 23],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'P', 'B', 'A', 'B', 'C'],
#   'maximum': [5, 7, 0, 14, 9, 19, 47],
#   'minimum': [5, 7, 0, 14, 9, 19, 47],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'A', 'A', 'B', 'B'],
#   'maximum': [13, 17, 8, 10, 20, 14],
#   'minimum': [5, 17, 11, 13, 20, 26],
#   'moyenne': None,
#   'nombre': 11},
#  {'_id': ['B', 'B', 'A', 'C'],
#   'maximum': [24, 19, 8, 35],
#   'minimum': [18, 20, 12, 4],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['A', 'A', 'B', 'B', 'B', 'B'],
#   'maximum': [10, 12, 20, 24, 22, 14],
#   'minimum': [9, 11, 27, 18, 19, 24],
#   'moyenne': None,
#   'nombre': 5},
#  {'_id': ['A', 'C', 'A', 'A', 'B', 'P', 'A', 'C', 'A'],
#   'maximum': [12, 4, 12, 11, 26, 3, 12, 36, 2],
#   'minimum': [12, 4, 12, 11, 26, 3, 12, 36, 2],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'B', 'A', 'B', 'A', 'P'],
#   'maximum': [12, 5, 16, 9, 17, 10, 4],
#   'minimum': [12, 5, 16, 9, 17, 10, 4],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'B', 'B', 'A', 'B'],
#   'maximum': [41, 13, 27, 15, 12, 16],
#   'minimum': [26, 11, 18, 19, 12, 19],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'C', 'C', 'A', 'A', 'B'],
#   'maximum': [12, 39, 47, 9, 11, 14],
#   'minimum': [11, 43, 44, 6, 13, 24],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'B'],
#   'maximum': [13, 26],
#   'minimum': [2, 15],
#   'moyenne': None,
#   'nombre': 189},
#  {'_id': ['A', 'B', 'C', 'A', 'A', 'A', 'C'],
#   'maximum': [11, 22, 31, 13, 12, 11, 46],
#   'minimum': [11, 22, 31, 13, 12, 11, 46],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'C', 'B'],
#   'maximum': [27, 33, 22],
#   'minimum': [15, 29, 23],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['B', 'A', 'P', 'B', 'B', 'A', 'A'],
#   'maximum': [21, 11, 9, 14, 17, 12, 7],
#   'minimum': [21, 11, 9, 14, 17, 12, 7],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'B', 'P', 'A', 'A', 'A'],
#   'maximum': [7, 18, 18, 2, 11, 13, 12],
#   'minimum': [7, 18, 18, 2, 11, 13, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'A', 'P', 'A', 'C', 'B'],
#   'maximum': [48, 23, 6, 0, 13, 46, 14],
#   'minimum': [48, 23, 6, 0, 13, 46, 14],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'B'],
#   'maximum': [36, 23, 18],
#   'minimum': [2, 26, 17],
#   'moyenne': None,
#   'nombre': 11},
#  {'_id': ['B', 'A', 'P', 'A'],
#   'maximum': [25, 8, 4, 7],
#   'minimum': [25, 8, 4, 7],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'B', 'C', 'C', 'B'],
#   'maximum': [17, 12, 25, 41, 51, 19],
#   'minimum': [17, 12, 25, 41, 51, 19],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'C', 'C', 'A', 'B'],
#   'maximum': [13, 5, 6, 29, 7, 11, 16],
#   'minimum': [13, 5, 6, 29, 7, 11, 16],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'A', 'B', 'B', 'B'],
#   'maximum': [35, 12, 15, 26, 27],
#   'minimum': [35, 12, 15, 26, 27],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'A', 'C', 'B'],
#   'maximum': [27, 14, 11, 29, 19],
#   'minimum': [27, 14, 11, 29, 19],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'B', 'B', 'B', 'B', 'B'],
#   'maximum': [29, 19, 26, 20, 14, 17],
#   'minimum': [29, 19, 26, 20, 14, 17],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'B', 'A', 'B', 'B', 'P'],
#   'maximum': [22, 25, 27, 12, 23, 27, 14],
#   'minimum': [22, 25, 27, 12, 23, 27, 14],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'A', 'P', 'A', 'B'],
#   'maximum': [13, 8, 6, 11, 2, 11, 27],
#   'minimum': [9, 5, 12, 9, 9, 10, 22],
#   'moyenne': None,
#   'nombre': 5},
#  {'_id': ['C', 'A', 'A', 'A', 'B', 'A'],
#   'maximum': [29, 13, 7, 9, 19, 9],
#   'minimum': [29, 13, 7, 9, 19, 9],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'C', 'A', 'B', 'A'],
#   'maximum': [27, 59, 13, 26, 11],
#   'minimum': [17, 73, 10, 25, 8],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['A', 'B', 'A', 'C', 'C', 'C'],
#   'maximum': [2, 19, 12, 15, 44, 31],
#   'minimum': [2, 19, 12, 15, 44, 31],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'B', 'A', 'B', 'C'],
#   'maximum': [18, 10, 16, 13, 17, 3],
#   'minimum': [14, 5, 15, 5, 14, 40],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'B', 'B', 'B', 'P', 'B', 'B'],
#   'maximum': [12, 7, 18, 15, 24, 3, 17, 21],
#   'minimum': [12, 7, 18, 15, 24, 3, 17, 21],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'B', 'B', 'B', 'A'],
#   'maximum': [20, 26, 23, 17, 14, 9],
#   'minimum': [19, 15, 25, 15, 27, 13],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'A', 'B', 'A', 'C', 'A'],
#   'maximum': [9, 10, 13, 20, 11, 6, 5],
#   'minimum': [9, 10, 13, 20, 11, 6, 5],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'A', 'C', 'B'],
#   'maximum': [42, 10, 13, 5, 21],
#   'minimum': [33, 7, 12, 3, 16],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'A', 'A', 'C', 'A', 'C'],
#   'maximum': [4, 11, 2, 2, 55, 13, 4],
#   'minimum': [4, 11, 2, 2, 55, 13, 4],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'C', 'A', 'A', 'C'],
#   'maximum': [23, 7, 13, 8, 42],
#   'minimum': [23, 7, 13, 8, 42],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'A', 'A', 'A', 'P'],
#   'maximum': [12, 10, 11, 10, 13, 7, 10],
#   'minimum': [2, 13, 11, 6, 13, 13, 6],
#   'moyenne': None,
#   'nombre': 5},
#  {'_id': ['A', 'A', 'B', 'B', 'A', 'A', 'C'],
#   'maximum': [13, 13, 19, 27, 12, 12, 33],
#   'minimum': [13, 13, 19, 27, 12, 12, 33],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'B', 'B', 'A', 'C'],
#   'maximum': [35, 11, 21, 14, 8, 9],
#   'minimum': [27, 11, 17, 19, 11, 29],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'B', 'A', 'B', 'A', 'B', 'A'],
#   'maximum': [13, 23, 6, 14, 10, 15, 7],
#   'minimum': [13, 23, 6, 14, 10, 15, 7],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'B', 'B', 'B'],
#   'maximum': [20, 12, 24, 16, 16],
#   'minimum': [16, 13, 14, 27, 16],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['A', 'A', 'P', 'A', 'A', 'A', 'B'],
#   'maximum': [11, 12, 2, 12, 12, 10, 22],
#   'minimum': [9, 11, 5, 5, 5, 10, 17],
#   'moyenne': None,
#   'nombre': 4},
#  {'_id': ['B', 'B', 'B', 'A', 'A', 'C'],
#   'maximum': [27, 15, 19, 5, 13, 38],
#   'minimum': [27, 15, 19, 5, 13, 38],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['C', 'A', 'A', 'B', 'B', 'A', 'A'],
#   'maximum': [28, 11, 5, 14, 25, 12, 12],
#   'minimum': [28, 11, 5, 14, 25, 12, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'C', 'A', 'B', 'B'],
#   'maximum': [34, 35, 9, 17, 16],
#   'minimum': [34, 35, 9, 17, 16],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'B', 'C', 'A', 'A'],
#   'maximum': [24, 14, 24, 2, 7, 13],
#   'minimum': [24, 14, 24, 2, 7, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'C', 'B', 'B', 'A'],
#   'maximum': [20, 11, 30, 27, 18, 9],
#   'minimum': [20, 11, 30, 27, 18, 9],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'P', 'B', 'A', 'A', 'C'],
#   'maximum': [12, 14, 10, 23, 10, 8, 3],
#   'minimum': [12, 14, 10, 23, 10, 8, 3],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'C', 'P'],
#   'maximum': [7, 51, 37, 2],
#   'minimum': [7, 51, 37, 2],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'B', 'B', 'B', 'C', 'C'],
#   'maximum': [12, 10, 25, 27, 19, 39, 10],
#   'minimum': [9, 12, 21, 15, 24, 28, 30],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['Z', 'B', 'A', 'A', 'A', 'A', 'A'],
#   'maximum': [19, 16, 10, 12, 12, 2, 12],
#   'minimum': [19, 16, 10, 12, 12, 2, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'P', 'B', 'A'],
#   'maximum': [12, 12, 5, 26, 7],
#   'minimum': [11, 7, 9, 18, 11],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['A', 'B', 'P', 'A', 'B', 'A', 'A'],
#   'maximum': [12, 25, 9, 12, 27, 12, 11],
#   'minimum': [12, 25, 9, 12, 27, 12, 11],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'P', 'A', 'A'],
#   'maximum': [20, 9, 3, 7, 12],
#   'minimum': [20, 9, 3, 7, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'B', 'C', 'B', 'B'],
#   'maximum': [13, 17, 10, 18, 14],
#   'minimum': [10, 27, 32, 21, 22],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'P', 'A', 'A', 'A', 'B', 'B'],
#   'maximum': [8, 5, 2, 12, 10, 8, 25, 16],
#   'minimum': [8, 5, 2, 12, 10, 8, 25, 16],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'A', 'B'],
#   'maximum': [44, 12, 22],
#   'minimum': [9, 2, 18],
#   'moyenne': None,
#   'nombre': 13},
#  {'_id': ['Z', 'A', 'A', 'B', 'A', 'B', 'A'],
#   'maximum': [36, 11, 12, 22, 9, 24, 11],
#   'minimum': [24, 12, 12, 15, 12, 18, 10],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'B', 'A', 'A', 'P'],
#   'maximum': [12, 19, 2, 9, 2],
#   'minimum': [9, 17, 10, 13, 3],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'B', 'A', 'P', 'A', 'C', 'B'],
#   'maximum': [3, 19, 12, 3, 10, 9, 14],
#   'minimum': [3, 19, 12, 3, 10, 9, 14],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'C', 'A', 'C', 'B'],
#   'maximum': [19, 27, 38, 8, 35, 19],
#   'minimum': [19, 27, 38, 8, 35, 19],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'A', 'A', 'B', 'A'],
#   'maximum': [21, 14, 8, 7, 18, 10],
#   'minimum': [17, 17, 10, 7, 18, 13],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'A', 'A', 'P', 'B'],
#   'maximum': [12, 10, 12, 0, 16],
#   'minimum': [3, 13, 7, 10, 14],
#   'moyenne': None,
#   'nombre': 5},
#  {'_id': ['A', 'A', 'C', 'B', 'B', 'C', 'B'],
#   'maximum': [12, 13, 42, 25, 19, 40, 22],
#   'minimum': [10, 6, 50, 26, 23, 2, 14],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'C', 'A', 'C', 'A', 'B'],
#   'maximum': [10, 29, 13, 30, 11, 15],
#   'minimum': [10, 29, 13, 30, 11, 15],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'B', 'A', 'A', 'A', 'P', 'A'],
#   'maximum': [20, 25, 11, 13, 11, 4, 12],
#   'minimum': [20, 25, 11, 13, 11, 4, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'P', 'A', 'B', 'P'],
#   'maximum': [10, 7, 9, 4, 13, 22, 4],
#   'minimum': [10, 7, 9, 4, 13, 22, 4],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'C', 'B', 'B', 'P', 'B', 'B', 'B', 'C'],
#   'maximum': [8, 32, 14, 23, 14, 25, 17, 24, 13],
#   'minimum': [8, 32, 14, 23, 14, 25, 17, 24, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'P', 'A', 'A', 'A', 'A'],
#   'maximum': [12, 2, 6, 6, 13, 13],
#   'minimum': [11, 9, 11, 8, 10, 13],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['B', 'B', 'A', 'P', 'A', 'B', 'A'],
#   'maximum': [18, 20, 10, 17, 13, 15, 12],
#   'minimum': [18, 20, 10, 17, 13, 15, 12],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'B', 'B', 'C'],
#   'maximum': [12, 8, 7, 15, 27, 29],
#   'minimum': [10, 12, 7, 26, 22, 9],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'P', 'C', 'A'],
#   'maximum': [12, 2, 11, 9],
#   'minimum': [7, 4, 46, 10],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['C', 'B', 'B', 'C', 'C', 'B', 'P', 'A'],
#   'maximum': [35, 27, 22, 2, 36, 14, 9, 9],
#   'minimum': [35, 27, 22, 2, 36, 14, 9, 9],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'A', 'P', 'A', 'A'],
#   'maximum': [21, 7, 13, 5, 13, 8],
#   'minimum': [17, 12, 11, 3, 11, 8],
#   'moyenne': None,
#   'nombre': 3},
#  {'_id': ['A', 'A', 'C', 'P', 'A', 'A', 'A', 'B'],
#   'maximum': [13, 10, 2, 9, 11, 7, 11, 16],
#   'minimum': [13, 10, 2, 9, 11, 7, 11, 16],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'B', 'P', 'A', 'B'],
#   'maximum': [12, 11, 9, 16, 4, 7, 20],
#   'minimum': [12, 8, 9, 27, 5, 9, 15],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['B', 'C', 'B', 'B', 'C', 'B', 'B'],
#   'maximum': [27, 47, 20, 24, 40, 19, 27],
#   'minimum': [27, 47, 20, 24, 40, 19, 27],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['Z', 'B', 'A', 'B', 'B', 'B', 'A'],
#   'maximum': [23, 15, 13, 18, 23, 16, 13],
#   'minimum': [23, 15, 13, 18, 23, 16, 13],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['B', 'A', 'B', 'A', 'A', 'C'],
#   'maximum': [24, 10, 17, 11, 12, 36],
#   'minimum': [20, 12, 26, 0, 12, 54],
#   'moyenne': None,
#   'nombre': 2},
#  {'_id': ['A', 'B', 'A', 'P', 'B', 'A', 'B'],
#   'maximum': [11, 23, 12, 5, 23, 10, 15],
#   'minimum': [11, 23, 12, 5, 23, 10, 15],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'P', 'A', 'A', 'B'],
#   'maximum': [13, 12, 11, 12, 7, 27],
#   'minimum': [5, 12, 5, 13, 12, 18],
#   'moyenne': None,
#   'nombre': 9},
#  {'_id': ['A', 'B', 'B', 'B', 'A', 'A', 'C'],
#   'maximum': [11, 15, 17, 16, 11, 12, 32],
#   'minimum': [11, 15, 17, 16, 11, 12, 32],
#   'moyenne': None,
#   'nombre': 1},
#  {'_id': ['A', 'A', 'A', 'B', 'A', 'C'],
#   'maximum': [12, 12, 12, 23, 9, 31],
#   'minimum': [2, 2, 8, 26, 10, 32],
#   'moyenne': None,
#   'nombre': 6},
#  {'_id': ['A', 'A', 'C', 'B', 'C', 'B'],
#   'maximum': [10, 5, 4, 18, 29, 23],
#   'minimum': [10, 5, 4, 18, 29, 23],
#   'moyenne': None,
#   'nombre': 1}]

# %%
res = db.restaurants.aggregate([
    {"$unwind" : "$grades"},
    {"$group" : { 
        "_id": "$grades.grade", 
        "nombre" : {"$sum" : 1 },
        "moyenne" : {"$avg" : "$grades.score"},
        "minimum" : {"$min" : "$grades.score"},
        "maximum" : {"$max" : "$grades.score"}
    }}
])
affiche(res)
# Out:
# [{'_id': 'P',
#   'maximum': 43,
#   'minimum': 0,
#   'moyenne': 5.506265664160401,
#   'nombre': 1197},
#  {'_id': 'A',
#   'maximum': 27,
#   'minimum': 0,
#   'moyenne': 9.021954029147022,
#   'nombre': 74656},
#  {'_id': 'Not Yet Graded',
#   'maximum': 75,
#   'minimum': 0,
#   'moyenne': 15.853515625,
#   'nombre': 525},
#  {'_id': 'B',
#   'maximum': 57,
#   'minimum': -1,
#   'moyenne': 20.002459731809886,
#   'nombre': 12603},
#  {'_id': 'Z',
#   'maximum': 71,
#   'minimum': -1,
#   'moyenne': 23.702318623784592,
#   'nombre': 1337},
#  {'_id': 'C',
#   'maximum': 131,
#   'minimum': -1,
#   'moyenne': 30.70079491255962,
#   'nombre': 3145}]

# %% [markdown]
# **9. Créer un `DataFrame` contenant les restaurants en ligne et en colonne le score moyen obtenu pour chaque grade possible. Si un restaurant n'a pas eu d'évaluation d'un grade, nous aurons une valeur absente.**
#
# Si nous regardons le nombre de restaurants par nom de ceux-ci, nous remarquons qu'il y a des restaurants avec le même nom (des chaînes comme *Starbucks* ou *Subway* par exemple).

# %%
res = db.restaurants.aggregate([
    { "$group": { "_id": "$name", "nb": { "$sum": 1 } } },
    { "$sort": { "nb": -1 } },
    { "$limit": 10 }
])
affiche(res)
# Out:
# [{'_id': 'Subway', 'nb': 421},
#  {'_id': 'Starbucks Coffee', 'nb': 223},
#  {'_id': "Mcdonald'S", 'nb': 208},
#  {'_id': "Dunkin' Donuts", 'nb': 206},
#  {'_id': 'Dunkin Donuts', 'nb': 200},
#  {'_id': '', 'nb': 151},
#  {'_id': 'Kennedy Fried Chicken', 'nb': 88},
#  {'_id': 'Crown Fried Chicken', 'nb': 81},
#  {'_id': 'Burger King', 'nb': 80},
#  {'_id': "Domino'S Pizza", 'nb': 67}]

# %% [markdown]
# Nous allons donc faire un regroupement par identifiant de restaurant (`restaurant_id`) et par `grade`, pour calculer le score moyen. Nous voyons ici les premiers résultats de l'aggrégation.

# %%
res = db.restaurants.aggregate([
    { "$unwind" : "$grades"},
    { "$group" : { 
        "_id": { "restaurant_id": "$restaurant_id", "grade": "$grades.grade" }, 
        "moy" : { "$avg" : "$grades.score" }
    } }
])
l = list(res)
l[:10]
# Out:
# [{'_id': {'restaurant_id': '50018661', 'grade': 'Not Yet Graded'}, 'moy': 2.0},
#  {'_id': {'restaurant_id': '50018622', 'grade': 'Not Yet Graded'},
#   'moy': 19.0},
#  {'_id': {'restaurant_id': '50018608', 'grade': 'A'}, 'moy': 12.0},
#  {'_id': {'restaurant_id': '50018587', 'grade': 'Not Yet Graded'}, 'moy': 2.0},
#  {'_id': {'restaurant_id': '50018565', 'grade': 'Not Yet Graded'}, 'moy': 0.0},
#  {'_id': {'restaurant_id': '50018547', 'grade': 'Not Yet Graded'},
#   'moy': 29.0},
#  {'_id': {'restaurant_id': '50018535', 'grade': 'Not Yet Graded'},
#   'moy': 47.0},
#  {'_id': {'restaurant_id': '50018514', 'grade': 'Not Yet Graded'}, 'moy': 9.0},
#  {'_id': {'restaurant_id': '50018480', 'grade': 'Not Yet Graded'},
#   'moy': 43.0},
#  {'_id': {'restaurant_id': '50018450', 'grade': 'Not Yet Graded'}, 'moy': 0.0}]

# %% [markdown]
# Ensuite, on créé un `DataFrame` *à la main*, en récupérant la liste des identifiants, la liste des grades et la liste des scores moyens. Ce qui nous donne à la fin le `DataFrame` suivant.

# %%
df = pd.DataFrame({
    "restaurant_id"  : [r["_id"]["restaurant_id"] for r in l],
    "grade": [r["_id"]["grade"] for r in l],
    "score": [r["moy"] for r in l]
})
df.head()
# Out:
#   restaurant_id           grade  score
# 0      50018661  Not Yet Graded    2.0
# 1      50018622  Not Yet Graded   19.0
# 2      50018608               A   12.0
# 3      50018587  Not Yet Graded    2.0
# 4      50018565  Not Yet Graded    0.0

# %% [markdown]
# Il faut maintenant transformer ce `DataFrame` en faisant l'*inverse* de la fonction `melt()`. Pour cela, nous disposons de la fonction `pivot()` à partir du `DataFrame`. Cette fonction prend trois paramètre :
#
# - `index` : identifiant de chaque ligne (ici, l'identifiant des restaurants)
# - `columns` : noms des colonnes (ici, chaque grade)
# - `value` : valeurs des cellules (ici, score moyen pour un restaurant pour un grade)

# %%
dfbis = df.pivot(index = "restaurant_id", columns = "grade", values = "score")
dfbis.head()
# Out:
# grade                  A     B   C  Not Yet Graded   P     Z
# restaurant_id
# 30075445        6.750000  14.0 NaN             NaN NaN   NaN
# 30112340       10.666667  23.0 NaN             NaN NaN   NaN
# 30191841        9.250000   NaN NaN             NaN NaN   NaN
# 40356018        9.000000   NaN NaN             NaN NaN   NaN
# 40356068       13.000000  25.0 NaN             NaN NaN  20.0

# %% [markdown]
# Au final, nous regardons les informations de notre `DataFrame` ainsi créé. Nous remarquons que la plupart ont eu un grade `A`, et plusieurs n'ont pas encore été évalué.

# %%
dfbis.shape
# Out:
# (24621, 6)

# %%
dfbis.count()
# Out:
# grade
# A                 23440
# B                  8280
# C                  2708
# Not Yet Graded      512
# P                  1154
# Z                  1337
# dtype: int64

# %% [markdown]
# Nous récupérons ici les informations des restaurants (nom - `name` - et quartier - `borough`) pour les ajouter à notre table précédente. Ici, nous récupérons juste les informations que l'on souhaite.

# %%
infos = db.restaurants.find({}, { "_id": 0, "restaurant_id": 1, "name": 1, "borough": 1 })
infos_df = pd.DataFrame(list(infos))

# %% [markdown]
# Pour réaliser une jointure, nous avons la fonction `join()` qui réalise une jointure sur les `index` des lignes par défaut. La fonction `set_index()` permet de définir cet `index` de lignes pour les informations des restaurants, avant de faire la jointure.

# %%
final = dfbis.join(infos_df.set_index("restaurant_id"))
final.head()
# Out:
#                        A     B   C  Not Yet Graded   P     Z    borough  \
# restaurant_id
# 30075445        6.750000  14.0 NaN             NaN NaN   NaN      Bronx
# 30112340       10.666667  23.0 NaN             NaN NaN   NaN   Brooklyn
# 30191841        9.250000   NaN NaN             NaN NaN   NaN  Manhattan
# 40356018        9.000000   NaN NaN             NaN NaN   NaN   Brooklyn
# 40356068       13.000000  25.0 NaN             NaN NaN  20.0     Queens
#
#                                          name
# restaurant_id
# 30075445                Morris Park Bake Shop
# 30112340                              Wendy'S
# 30191841       Dj Reynolds Pub And Restaurant
# 40356018                      Riviera Caterer
# 40356068                   Tov Kosher Kitchen

# %% [markdown]
# Avec un `DataFrame` ainsi créé, il est maintenant possible, par exemple, de calculer les scores moyens de chaque grade, pour chaque quartier (ici, dans `python`).

# %%
final.groupby("borough").mean()
# Out:
#                       A          B          C  Not Yet Graded         P  \
# borough
# Bronx          8.837432  19.789996  28.903614       14.046512  5.669065
# Brooklyn       8.941166  19.869812  28.732290       16.412587  5.353474
# Manhattan      8.935430  19.848022  31.182162       17.836478  5.680101
# Missing        8.410000  22.000000  43.500000             NaN       NaN
# Queens         9.117012  19.879747  31.122008       14.223881  5.283582
# Staten Island  9.331491  19.365970  32.820000       12.848485  6.684211
#
#                        Z
# borough
# Bronx          22.376238
# Brooklyn       23.449123
# Manhattan      24.492228
# Missing              NaN
# Queens         23.509259
# Staten Island  19.770833
